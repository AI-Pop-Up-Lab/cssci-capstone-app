# %% [markdown]
# # Unique column value generation tool
#
# this notebook generates a data structure for the country_data_info.json in ai-popup-lab-backend/country_data
#
# this is then fed through the backend to the frontend to give the options for dropdowns when the user wants to choose demographics to see more specific demographic tables (or for choosing the persona)

# %%
import pandas as pd

df = pd.read_csv(r'ai-popup-lab-backend\country_data\daily_sample\netherlands_daily_sample.csv') #replace with daily sample of country you wish to generate for (rather than strat frame where values may not be translated or edited correctly)
df.head()
# Out:
#    index     gm_code    municipality  gender age_group          education  \
# 0      0  GM1883      Sittard-Geleen  female     45-55  Havo, vwo, mbo2-4
# 1      1  GM1742      Rijssen-Holten    male     35-45  Hbo-, wo-bachelor
# 2      2  GM1876         Bronckhorst    male     45-55  Havo, vwo, mbo2-4
# 3      3  GM0363           Amsterdam  female     35-45  Havo, vwo, mbo2-4
# 4      4  GM1955         Montferland  female     65-75  Havo, vwo, mbo2-4
#
#   vote_2030
# 0       CDA
# 1       BBB
# 2       CDA
# 3       D66
# 4       CDA

# %%
# place here the relevant columns for the demographic choices in the front-end
relevant_columns = ["municipality", "gender", "age_group", "education"]


# create dictionary to hold unique values for each relevant column
unique_values = {col: df[col].dropna().unique().tolist()
                 for col in relevant_columns}

# %% [markdown]
# # output
#
# now copy and past the resulting dictionary printed below into the *country_data_info.json* file, in the correct country, value of key "column_unique_vals"

# %%
import json

print(json.dumps(unique_values))
# Out:
# {"municipality": ["Sittard-Geleen", "Rijssen-Holten", "Bronckhorst", "Amsterdam", "Montferland", "Alphen aan den Rijn", "Emmen", "Oss", "Roosendaal", "Oldenzaal", "Wijdemeren", "Noordoostpolder", "Hoorn", "Teylingen", "Rotterdam", "Oldambt", "Leiden", "Amersfoort", "Haarlemmermeer", "Breda", "Enschede", "Almelo", "Doetinchem", "Lochem", "Voorne aan Zee", "Maastricht", "Harderwijk", "Beverwijk", "Oirschot", "Borne", "Leeuwarden", "Hillegom", "Geldrop-Mierlo", "'s-Gravenhage (gemeente)", "Leidschendam-Voorburg", "Gorinchem", "Waalwijk", "Alkmaar", "Westland", "Hoogeveen", "IJsselstein", "Ooststellingwerf", "Altena", "Wageningen", "Dordrecht", "Purmerend", "Baarn", "Barneveld", "Hollands Kroon", "Arnhem", "Oldebroek", "Utrecht (gemeente)", "Sluis", "Valkenswaard", "Zaanstad", "Leudal", "Nijkerk", "Berg en Dal", "Maasgouw", "Zeist", "Horst aan de Maas", "Valkenburg aan de Geul", "Almere", "Hof van Twente", "Dijk en Waard", "Eindhoven", "Nijmegen", "Utrechtse Heuvelrug", "Vlissingen", "Hengelo (O.)", "Apeldoorn", "Midden-Groningen", "Groningen (gemeente)", "Stichtse Vecht", "Heusden", "Amstelveen"], "gender": ["female", "male"], "age_group": ["45-55", "35-45", "65-75", "25-35", "55-65", "15-25"], "education": ["Havo, vwo, mbo2-4", "Hbo-, wo-bachelor", "Hbo-, wo-master, doctor", "Basisonderwijs", "Vmbo, havo-/vwo-onderbouw, mbo1"]}
