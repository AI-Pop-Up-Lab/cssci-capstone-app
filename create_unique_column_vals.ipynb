# %% [markdown]
# # Unique column value generation tool
#
# this notebook generates a data structure for the country_data_info.json in ai-popup-lab-backend/country_data
#
# this is then fed through the backend to the frontend to give the options for dropdowns when the user wants to choose demographics to see more specific demographic tables (or for choosing the persona)

# %%
import pandas as pd

df = pd.read_csv(r'ai-popup-lab-backend\country_data\daily_sample\sweden_daily_sample.csv') #replace with daily sample of country you wish to generate for (rather than strat frame where values may not be translated or edited correctly)
df.head()
# Out:
#    index  cell_id age_group gender municipality  \
# 0      0     5893     41-50  Women      Alvesta
# 1      1    21386     51-60  Women       Norsjö
# 2      2    13907     18-22    Men     Alingsås
# 3      3    10835     51-60  Women   Kungsbacka
# 4      4     1378     61-70  Women    Stockholm
#
#                             education_level           past_vote      prob  \
# 0     Tertiary education, 2 years or longer    Green Party (MP)  0.064193
# 1  Tertiary education, shorter than 2 years        Did not vote  0.106426
# 2                    Upper secondary school    Centre Party (C)  0.062880
# 3                    Upper secondary school  Moderate Party (M)  0.312650
# 4  Tertiary education, shorter than 2 years  Moderate Party (M)  0.182569
#
#     expected_N               party  expected_N_raked  prob_raked  \
# 0    22.178535    Green Party (MP)         22.036577    0.063782
# 1     3.160856        Did not vote          1.958099    0.065929
# 2    64.728912    Centre Party (C)         48.560986    0.047174
# 3   735.509346  Moderate Party (M)        793.076451    0.337121
# 4  1614.326162  Moderate Party (M)       1545.967750    0.174838
#
#             vote_2026
# 0    Green Party (MP)
# 1        Did not vote
# 2    Centre Party (C)
# 3  Moderate Party (M)
# 4  Moderate Party (M)

# %%
# place here the relevant columns for the demographic choices in the front-end
relevant_columns = ["age_group", "gender", "municipality", "education_level", "vote_2026"]


# create dictionary to hold unique values for each relevant column
unique_values = {col: df[col].dropna().unique().tolist()
                 for col in relevant_columns}

# %% [markdown]
# # output
#
# now copy and past the resulting dictionary printed below into the *country_data_info.json* file, in the correct country, value of key "column_unique_vals"

# %%
import json

print(json.dumps(unique_values))
# Out:
# {"age_group": ["41-50", "51-60", "18-22", "61-70", "31-40", "71-104", "23-30"], "gender": ["Women", "Men"], "municipality": ["Alvesta", "Norsj\u00f6", "Alings\u00e5s", "Kungsbacka", "Stockholm", "Tyres\u00f6", "Falun", "M\u00f6lndal", "J\u00e4rf\u00e4lla", "Skellefte\u00e5", "V\u00e4ster\u00e5s", "Norrt\u00e4lje", "Nacka", "Link\u00f6ping", "Helsingborg", "Karlshamn", "Kinda", "Stenungsund", "\u00c5tvidaberg", "Vetlanda", "Svedala", "Karlstad", "Solna", "Lund", "Varberg", "Haninge", "Partille", "T\u00e4by", "Ume\u00e5", "\u00d6rebro", "G\u00f6teborg", "Burl\u00f6v", "Malm\u00f6", "Huddinge", "Hudiksvall", "\u00d6sthammar", "Landskrona", "Trelleborg", "Forshaga", "\u00c5re", "G\u00e4vle", "Sundsvall", "Salem", "Norrk\u00f6ping", "Ljungby", "Katrineholm", "Surahammar", "J\u00f6nk\u00f6ping", "Eskilstuna", "Ystad", "Ljusnarsberg", "Sollentuna", "Lule\u00e5", "Torsby", "Vallentuna", "Trollh\u00e4ttan", "Eda", "N\u00e4ssj\u00f6", "Mora", "Ale", "Motala", "Mariestad", "Ljusdal", "B\u00e5stad", "Kung\u00e4lv", "Sk\u00f6vde", "\u00c4ngelholm", "Kil", "Karlskrona", "Eker\u00f6", "Bengtsfors", "Uppsala", "V\u00e4stervik", "Lidk\u00f6ping", "Tierp", "\u00d6desh\u00f6g", "Sollefte\u00e5", "Borl\u00e4nge", "Esl\u00f6v", "Heby", "Kumla", "\u00c4lvdalen", "Gotland", "H\u00e5bo", "Mullsj\u00f6", "\u00d6stersund", "V\u00e4rnamo", "Str\u00e4ngn\u00e4s", "Botkyrka", "\u00d6cker\u00f6", "Eksj\u00f6", "Gullsp\u00e5ng", "H\u00f6gan\u00e4s", "Knivsta", "Vara", "S\u00f6dert\u00e4lje", "V\u00e4xj\u00f6", "Krokom", "Gislaved", "Hedemora", "Enk\u00f6ping", "Kristianstad", "Sandviken", "Habo", "Tibro", "\u00d6ster\u00e5ker", "\u00c4lvkarleby", "Bor\u00e5s", "Sala", "Hylte", "Nyk\u00f6ping", "Hultsfred", "Essunga", "Arvika", "Halmstad", "Sundbyberg", "Berg", "\u00c5sele", "H\u00e4rn\u00f6sand", "Tran\u00e5s", "V\u00e4rmd\u00f6", "Arboga", "Finsp\u00e5ng", "K\u00f6ping", "Simrishamn", "Br\u00e4cke", "Orust", "Pite\u00e5", "Timr\u00e5", "Lax\u00e5", "Brom\u00f6lla", "Karlskoga", "Sigtuna", "Arvidsjaur", "Flen", "Staffanstorp", "Lysekil", "Skara", "Malung-S\u00e4len", "Kalmar", "Mellerud", "Lerum", "Gagnef", "Danderyd", "Falkenberg", "Skurup", "H\u00e4rjedalen", "Bolln\u00e4s", "V\u00e5rg\u00e5rda", "Vimmerby", "Lessebo", "Grums", "\u00d6rnsk\u00f6ldsvik", "Leksand", "Ronneby", "S\u00f6derhamn", "Lindesberg", "Robertsfors", "Karlsborg", "Bjuv", "Filipstad", "Kristinehamn", "\u00c4lmhult", "\u00c5rj\u00e4ng", "Klippan", "Bollebygd", "F\u00e4rgelanda", "Tomelilla", "Vindeln", "Tj\u00f6rn", "\u00d6vertorne\u00e5", "\u00c4lvsbyn", "Falk\u00f6ping", "Fagersta", "K\u00e4vlinge", "Nybro", "M\u00f6rbyl\u00e5nga", "Kramfors", "Sj\u00f6bo", "Pajala", "H\u00f6rby", "Liding\u00f6", "S\u00e4vsj\u00f6", "Hallsberg", "Upplands-Bro", "Ulricehamn", "H\u00f6\u00f6r", "\u00d6rkelljunga", "Oxel\u00f6sund", "Markaryd", "S\u00f6derk\u00f6ping", "Trosa", "Laholm", "Gnosj\u00f6", "Hallstahammar", "Str\u00f6msund", "Mj\u00f6lby", "Vaggeryd", "S\u00e4ffle", "Uddevalla", "G\u00f6tene", "H\u00e4ssleholm", "Lomma", "Tranemo", "Smedjebacken", "Tingsryd", "T\u00f6reboda", "Nyn\u00e4shamn", "Vaxholm", "Olofstr\u00f6m", "S\u00f6lvesborg", "H\u00e4rryda", "Gnesta", "\u00d6stra G\u00f6inge", "Kungs\u00f6r", "Nordanstig", "Avesta", "Hofors", "Emmaboda", "Nora", "Lekeberg", "Tanum", "Ludvika", "Soten\u00e4s", "Lilla Edet", "Lycksele", "Boxholm", "Orsa", "Degerfors", "H\u00e4llefors", "Uppvidinge", "Vansbro", "Vellinge", "Tors\u00e5s", "Hammar\u00f6", "Sorsele", "Kalix", "Oskarshamn", "Hjo", "Borgholm", "Storuman", "Nykvarn", "M\u00f6nster\u00e5s", "Valdemarsvik", "Str\u00f6mstad", "Upplands V\u00e4sby", "Norberg", "Sval\u00f6v", "Tidaholm", "Hagfors", "G\u00e4llivare", "\u00d6verkalix", "Haparanda", "Kiruna", "Storfors", "\u00c5storp", "Mal\u00e5", "S\u00e4ter", "V\u00e4nn\u00e4s", "Ydre", "Vadstena", "Ockelbo", "R\u00e4ttvik", "Osby", "Sunne", "Ovan\u00e5ker", "Askersund", "Vilhelmina", "\u00c5nge", "Aneby"], "education_level": ["Tertiary education, 2 years or longer", "Tertiary education, sho ...
