# %% [markdown]
# # Unique column value generation tool
#
# this notebook generates a data structure for the country_data_info.json in ai-popup-lab-backend/country_data
#
# this is then fed through the backend to the frontend to give the options for dropdowns when the user wants to choose demographics to see more specific demographic tables (or for choosing the persona)

# %%
import pandas as pd

df = pd.read_csv(r'ai-popup-lab-backend\country_data\daily_sample\denmark_daily_sample.csv') #replace with daily sample of country you wish to generate for (rather than strat frame where values may not be translated or edited correctly)
df.head()
# Out:
#    index  cell_id age_group gender municipality  \
# 0      0     7328     55-59  Women       Furesø
# 1      1    27541     35-39    Men        Vejle
# 2      2    19770     65-69  Women       Odense
# 3      3    14999     70-74    Men      Kolding
# 4      4     3040     50-54    Men  Brønderslev
#
#                                education_level                 party  \
# 0  H30 Vocational Education and Training (VET)        M: Moderaterne
# 1  H30 Vocational Education and Training (VET)   I: Liberal Alliance
# 2  H30 Vocational Education and Training (VET)        M: Moderaterne
# 3  H30 Vocational Education and Training (VET)  A: Socialdemokratiet
# 4  H30 Vocational Education and Training (VET)            V: Venstre
#
#        prob  expected_N  expected_N_raked  prob_raked              vote_2026
# 0  0.102641   41.390657         51.883401    0.128661        Moderaterne (M)
# 1  0.255261  296.720638        209.537472    0.180260   Liberal Alliance (I)
# 2  0.053134   81.733746         80.049415    0.052039        Moderaterne (M)
# 3  0.395053  432.081083        370.026628    0.338316  Socialdemokratiet (A)
# 4  0.126037   79.067721         82.669193    0.131778            Venstre (V)

# %%
# place here the relevant columns for the demographic choices in the front-end
relevant_columns = ["age_group", "gender", "municipality", "education_level", "vote_2026"]


# create dictionary to hold unique values for each relevant column
unique_values = {col: df[col].dropna().unique().tolist()
                 for col in relevant_columns}

# %% [markdown]
# # output
#
# now copy and past the resulting dictionary printed below into the *country_data_info.json* file, in the correct country, value of key "column_unique_vals"

# %%
import json

print(json.dumps(unique_values))
# Out:
# {"age_group": ["55-59", "35-39", "65-69", "70-74", "50-54", "25-29", "75-79", "30-34", "40-44", "60-64", "20-24", "45-49", "80-84", "90-94", "85-89"], "gender": ["Women", "Men"], "municipality": ["Fures\u00f8", "Vejle", "Odense", "Kolding", "Br\u00f8nderslev", "Aarhus", "Solr\u00f8d", "Aalborg", "Vesthimmerlands", "Skanderborg", "Copenhagen", "Favrskov", "Holstebro", "Haderslev", "Esbjerg", "K\u00f8ge", "Billund", "Frederikssund", "Helsing\u00f8r", "Roskilde", "Holb\u00e6k", "R\u00f8dovre", "N\u00e6stved", "Halsn\u00e6s", "Aller\u00f8d", "Hj\u00f8rring", "S\u00f8nderborg", "Mors\u00f8", "Faxe", "Hvidovre", "Ringsted", "Varde", "Syddjurs", "T\u00e5rnby", "Fredericia", "Gladsaxe", "Egedal", "Silkeborg", "Frederikshavn", "Rudersdal", "Viborg", "Ringk\u00f8bing-Skjern", "Aabenraa", "Albertslund", "Lejre", "Lyngby-Taarb\u00e6k", "Svendborg", "Herning", "Rebild", "H\u00f8rsholm", "Guldborgsund", "Greve", "Randers", "T\u00f8nder", "Lolland", "Sor\u00f8", "Horsens", "Fredensborg", "Slagelse", "Gribskov", "Frederiksberg", "Vejen", "Faaborg-Midtfyn", "Bornholm", "Hiller\u00f8d", "Nordfyns", "Kerteminde", "Nyborg", "Gentofte", "Ballerup", "Struer", "Middelfart", "H\u00f8je-Taastrup", "Norddjurs", "Mariagerfjord", "Ikast-Brande", "Drag\u00f8r", "Jammerbugt", "Thisted", "Odder", "Ish\u00f8j", "Odsherred", "Herlev", "Assens", "Kalundborg", "Skive", "Lemvig", "Vallensb\u00e6k", "Hedensted", "Vordingborg", "Langeland", "Br\u00f8ndby", "Stevns", "Glostrup"], "education_level": ["H30 Vocational Education and Training (VET)", "H70 Masters programs", "H50 Vocational bachelors educations", "H1030 Primary school 10th grade", "H2010 Upper secondary education, General (stx, hf, student courses)", "H1020 Primary school 7th-9th grade", "H40 Short cycle higher education", "H60 Bachelors programs", "H2020 Upper secondary education, General (hhx, htx)", "H90 Not stated"], "vote_2026": ["Moderaterne (M)", "Liberal Alliance (I)", "Socialdemokratiet (A)", "Venstre (V)", "Did not vote", "Socialistisk Folkeparti (F)", "Other - Right", "Other - Left", "Danmarksdemokraterne (\u00c6)", "Enhedslisten (\u00d8)", "Dansk Folkeparti (O)", "Liberal Alliance", "Other", "Radikale Venstre (B)"]}
