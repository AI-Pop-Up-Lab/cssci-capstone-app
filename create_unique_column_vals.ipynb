# %% [markdown]
# # Unique column value generation tool
#
# this notebook generates a data structure for the country_data_info.json in ai-popup-lab-backend/country_data
#
# this is then fed through the backend to the frontend to give the options for dropdowns when the user wants to choose demographics to see more specific demographic tables (or for choosing the persona)

# %%
import pandas as pd

df = pd.read_csv(r'ai-popup-lab-backend\country_data\daily_sample\netherlands_daily_sample.csv') #replace with daily sample of country you wish to generate for (rather than strat frame where values may not be translated or edited correctly)
df.head()
# Out:
#    index     gm_code      municipality  gender age_group  \
# 0      0  GM0297            Zaltbommel    male     45-55
# 1      1  GM0034                Almere    male     15-25
# 2      2  GM1940      De Fryske Marren    male     55-65
# 3      3  GM0610            Sliedrecht  female     55-65
# 4      4  GM0988                 Weert  female     25-35
#
#                          education     vote_2030
# 0                Hbo-, wo-bachelor           VVD
# 1                Havo, vwo, mbo2-4  Did not vote
# 2                Hbo-, wo-bachelor           CDA
# 3  Vmbo, havo-/vwo-onderbouw, mbo1        50PLUS
# 4  Vmbo, havo-/vwo-onderbouw, mbo1            SP

# %%
# place here the relevant columns for the demographic choices in the front-end
relevant_columns = ["municipality", "gender", "age_group", "education", "vote_2030"]


# create dictionary to hold unique values for each relevant column
unique_values = {col: df[col].dropna().unique().tolist()
                 for col in relevant_columns}

# %% [markdown]
# # output
#
# now copy and past the resulting dictionary printed below into the *country_data_info.json* file, in the correct country, value of key "column_unique_vals"

# %%
import json

print(json.dumps(unique_values))
# Out:
# {"municipality": ["Zaltbommel", "Almere", "De Fryske Marren", "Sliedrecht", "Weert", "Pijnacker-Nootdorp", "Zwolle", "Venlo", "Vlissingen", "Maastricht", "Leeuwarden", "Horst aan de Maas", "Arnhem", "Ede", "Westland", "Westerkwartier", "Land van Cuijk", "'s-Hertogenbosch", "Heerlen", "Goeree-Overflakkee", "Deurne", "Helmond", "Hilversum", "Veenendaal", "Zaanstad", "Oisterwijk", "Rotterdam", "Haarlem", "'s-Gravenhage (gemeente)", "Eindhoven", "Brummen", "Gouda", "Woensdrecht", "Haaksbergen", "Woerden", "Steenbergen", "Nissewaard", "Enschede", "Kerkrade", "Maashorst", "Breda", "Waalwijk", "Katwijk", "West Maas en Waal", "Zutphen", "Amsterdam", "Rucphen", "Elburg", "Teylingen", "Groningen (gemeente)", "Schagen", "Hoogeveen", "Castricum", "Moerdijk", "Gorinchem", "Utrecht (gemeente)", "Rheden", "Hellendoorn", "Noardeast-Frysl\u00e2n", "Ommen", "De Ronde Venen", "Hof van Twente", "Gooise Meren", "Delft", "Renkum", "Alkmaar", "Roosendaal", "Heerenveen", "Sluis", "Dinkelland", "Deventer", "Hoorn", "Nijmegen", "Tilburg", "Assen", "Voorst", "Velsen", "Oldebroek", "Zwartewaterland", "Putten", "Eemsdelta", "Amersfoort", "Smallingerland", "Hoeksche Waard", "Oss", "Heemstede", "Rijswijk (ZH.)", "Halderberge", "Utrechtse Heuvelrug", "Lingewaard", "Vlaardingen", "Noordenveld", "Zeist", "Bergen op Zoom", "Veldhoven", "Apeldoorn", "Stede Broec", "Midden-Groningen", "S\u00fadwest-Frysl\u00e2n", "Brunssum", "Sittard-Geleen", "Nieuwegein", "Haarlemmermeer", "Emmen", "Nijkerk", "Staphorst", "Amstelveen", "Waalre", "Kampen", "Noordwijk", "Ermelo", "Het Hogeland", "Meierijstad", "Barendrecht", "Doetinchem", "Duiven", "Raalte", "Kaag en Braassem", "Epe", "Leiden", "Tytsjerksteradiel", "Leiderdorp", "Wijchen", "Gulpen-Wittem", "Roermond", "Venray", "Goes", "Bodegraven-Reeuwijk", "Eijsden-Margraten", "Weststellingwerf", "Papendrecht", "Neder-Betuwe", "Waddinxveen", "Heusden", "Roerdalen", "Edam-Volendam", "Reimerswaal", "Asten", "Wierden", "Veendam", "Zuidplas", "Schiedam", "Steenwijkerland", "Laarbeek", "Borne", "Westervoort", "Huizen", "Harderwijk", "Baarn", "Overbetuwe", "Krimpenerwaard", "Voorne aan Zee", "Den Helder", "Geldrop-Mierlo", "Maassluis", "Heumen", "Wassenaar", "Oost Gelre", "Tubbergen", "Zoetermeer", "Bernheze", "Tynaarlo", "Oude IJsselstreek", "Dijk en Waard", "Zevenaar", "Almelo", "Valkenburg aan de Geul", "Alphen aan den Rijn", "Stadskanaal", "Oosterhout", "Leusden", "Enkhuizen", "Opsterland", "Beverwijk", "Culemborg", "Borger-Odoorn", "Leudal", "Stichtse Vecht", "IJsselstein", "Beekdaelen", "Ridderkerk", "Soest", "Lisse", "Twenterand", "West Betuwe", "Coevorden", "Losser", "Dantumadiel", "Westerveld", "Hengelo (O.)", "Oldambt", "Bloemendaal", "Winterswijk", "Beuningen", "Stein (L.)", "Wageningen", "Zwijndrecht", "Purmerend", "Lansingerland", "Achtkarspelen", "Maasdriel", "Waadhoeke", "Peel en Maas", "Hillegom", "Medemblik", "Dordrecht", "Oirschot", "Montferland", "Berkelland", "Drimmelen", "De Bilt", "Hulst", "Cranendonck", "Hendrik-Ido-Ambacht", "Borsele", "Drechterland", "Heemskerk", "Veere", "Lelystad", "Midden-Drenthe", "Ooststellingwerf", "Dongen", "Tiel", "Wijk bij Duurstede", "Nieuwkoop", "Rhenen", "Hardenberg", "Barneveld", "Loon op Zand", "Bunschoten", "Capelle aan den IJssel", "Houten", "Maasgouw", "Bergen (L.)", "De Wolden", "Diemen", "Heiloo", "Molenlanden", "Oldenzaal", "Vught", "Bunnik", "Bronckhorst", "Wijdemeren", "Midden-Delfland", "Eersel", "Westerwolde", "Aalsmeer", "Valkenswaard", "Nunspeet", "Someren", "Lochem", "Terneuzen", "Etten-Leur", "Sint-Michielsgestel", "Bladel", "Altena", "Zeewolde", "Zundert", "Albrandswaard", "Dalfsen", "Noordoostpolder", "Rijssen-Holten", "Landgraaf", "Leidschendam-Voorburg", "Oegstgeest", "Hollands Kroon", "Middelburg (Z.)", "Gilze en Rijen", "Vijfheerenlanden", "Heerde", "Goirle", "Schouwen-Duiveland", "Echt-Susteren", "Voorschoten", "Meppel", "Boxtel", "Olst-Wijhe", "Berg en Dal", "Tholen", "Urk", "Uithoorn", "Geertruidenberg", "Aa en Hunze", "Wormerland", "Beesel", "Hilvarenbeek" ...
