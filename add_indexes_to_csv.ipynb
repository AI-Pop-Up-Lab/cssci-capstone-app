# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("ai-popup-lab-backend/country_data/daily_sample/netherlands_daily_sample.csv")

# Add indexes (reset index to make current index a column, then create a new sequential index)
df = df.reset_index(drop=True)
df.index.name = 'index'


df = df.drop('N', axis=1)

# %%
# Save back to the same location and name
df.to_csv("ai-popup-lab-backend/country_data/daily_sample/netherlands_daily_sample.csv", index=True)
